# %%
import os
import json
from glob import glob

# 设置事件目录路径
EVENT_DIR = r"F:\\KeaPlus-Evaluation\\scripts\\output#2025-05-04-01-07-21\\events"

# 按时间顺序读取所有事件文件
event_files = sorted(glob(os.path.join(EVENT_DIR, "event_*.json")))

# 存储提取的数据
event_controls = []

for file_path in event_files:
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        event = data.get('event', {})
        view = event.get('view', {})
        
        control_info = {
            # 'tag': data.get('tag'),
            'event_type': event.get('event_type'),
            'class': view.get('class').split(".")[-1] if view.get('class') is not None else None ,
            'text': view.get('text'),
            'content_description': view.get('content_description'),
            'resource_id': view.get('resource_id'),
            # 'clickable': view.get('clickable'),
            # 'long_clickable': view.get('long_clickable'),
            # 'bounds': view.get('bounds'),
            # 'desc': view.get('desc'),
        }
        
        event_controls.append(control_info)
    
    except Exception as e:
        print(f"Failed to process {file_path}: {e}")

# ✅ 输出样例（前两项）
for item in event_controls[:10]:
    print(json.dumps(item, indent=2, ensure_ascii=False))
# Out:
# {
#   "event_type": "kill_app",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "intent",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "intent",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "scroll",
#   "class": "RecyclerView",
#   "text": null,
#   "content_description": null,
#   "resource_id": "com.amaze.filemanager.debug:id/listView"
# }
# {
#   "event_type": "touch",
#   "class": "ImageButton",
#   "text": null,
#   "content_description": "Properties",
#   "resource_id": "com.amaze.filemanager.debug:id/properties"
# }
# {
#   "event_type": "touch",
#   "class": "LinearLayout",
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "touch",
#   "class": "TextView",
#   "text": "CANCEL",
# ...

# %%
function_set=set()

for ctl in event_controls:
    text = ctl.get('text')
    content_description = ctl.get('content_description')
    
    if(text): function_set.add(text)
    elif(content_description): function_set.add(content_description)

function_set
# Out:
# {'\tMH',
# ...

# %%
# import os
# import json
# import csv
# from glob import glob

# EVENT_DIR = r"C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output5\\events"
# IMG_DIR = r"C:\Users\HP\Desktop\kea\ecnusse\Kea\output5\view_images"
# VALID_TEXTS = function_set  # 你提供的控件文本集合

# output = []

# for file_path in sorted(glob(os.path.join(EVENT_DIR, "event_*.json"))):
#     with open(file_path, 'r', encoding='utf-8') as f:
#         data = json.load(f)
    
#     view = data.get("event", {}).get("view", {})
#     text = view.get("text")
#     desc = view.get("content_description")
    
#     label = text or desc
#     if label in VALID_TEXTS:
#         view_str = view.get("view_str")
#         image_file = f"view_{view_str}.png"
#         image_path = os.path.join(IMG_DIR, image_file)
        
#         output.append({
#             "label": label,
#             "view_str": view_str,
#             "image_path": image_path,
#             "class": view.get("class")
#         })

# # 导出为CSV（可用于人工分类）
# with open("control_views.csv", "w", newline='', encoding='utf-8') as f:
#     writer = csv.DictWriter(f, fieldnames=output[0].keys())
#     writer.writeheader()
#     writer.writerows(output)

# %%
from collections import Counter

button_labels = {
  "\tMH": 9,
  "-------------------------------------\njava.lang.RuntimeException: An error occurred while executing doInBackground()\n\tat android.os.AsyncTask$4.done(AsyncTask.java:399)\n\tat java.util.concurrent.FutureTask.finishCompletion(FutureTask.java:383)\n\tat java.util.concurrent.FutureTask.setException(FutureTask.java:252)\n\tat java.util.concurrent.FutureTask.run(FutureTask.java:271)\n\tat java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1167)\n\tat java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:641)\n\tat java.lang.Thread.run(Thread.java:919)\nCaused by: java.lang.NoClassDefFoundError: Failed resolution of: Lorg/bouncycastle/asn1/ASN1ApplicationSpecific;\n\tat jcifs.spnego.NegTokenInit.parse(NegTokenInit.java:159)\n\tat jcifs.spnego.NegTokenInit.<init>(NegTokenInit.java:66)\n\tat jcifs.smb.NtlmPasswordAuthenticator.createContext(NtlmPasswordAuthenticator.java:243)\n\tat jcifs.smb.SmbSessionImpl.createContext(SmbSessionImpl.java:706)\n\tat jcifs.smb.SmbSessionImpl.sessionSetupSMB2(SmbSessionImpl.java:544)\n\tat jcifs.smb.SmbSessionImpl.sessionSetup(SmbSessionImpl.java:491)\n\tat jcifs.smb.SmbSessionImpl.send(SmbSessionImpl.java:369)\n\tat jcifs.smb.SmbSessionImpl.send(SmbSessionImpl.java:347)\n\tat jcifs.smb.SmbTreeImpl.treeConnect(SmbTreeImpl.java:611)\n\tat jcifs.smb.SmbTreeConnection.connectTree(SmbTreeConnection.java:614)\n\tat jcifs.smb.SmbTreeConnection.connectHost(SmbTreeConnection.java:568)\n\tat jcifs.smb.SmbTreeConnection.connectHost(SmbTreeConnection.java:489)\n\tat jcifs.smb.SmbEnumerationUtil.doShareEnum(SmbEnumerationUtil.java:145)\n\tat jcifs.smb.SmbEnumerationUtil.doEnum(SmbEnumerationUtil.java:218)\n\tat jcifs.smb.SmbEnumerationUtil.listFiles(SmbEnumerationUtil.java:279)\n\tat jcifs.smb.SmbFile.listFiles(SmbFile.java:1213)\n\tat com.amaze.filemanager.asynchronous.asynctasks.LoadFilesListTask.listSmb(LoadFilesListTask.java:689)\n\tat com.amaze.filemanager.asynchronous.asynctasks.LoadFilesListTask.doInBackground(LoadFilesListTask.java:162)\n\tat com.amaze.filemanager.asynchronous.asynctasks.LoadFilesListTask.doInBackground(LoadFilesListTask.java:91)\n\tat android.os.AsyncTask$3.call(AsyncTask.java:378)\n\tat java.util.concurrent.FutureTask.run(FutureTask.java:266)\n\t... 3 more\nCaused by: java.lang.ClassNotFoundException: Didn't find class \"org.bouncycastle.asn1.ASN1ApplicationSpecific\" on path: DexPathList[[zip file \"/data/app/com.amaze.filemanager.debug-vtRkPzSn-HtEKl56jcseUQ==/base.apk\"],nativeLibraryDirectories=[/data/app/com.amaze.filemanager.debug-vtRkPzSn-HtEKl56jcseUQ==/lib/x86, /data/app/com.amaze.filemanager.debug-vtRkPzSn-HtEKl56jcseUQ==/base.apk!/lib/x86, /system/lib, /system/product/lib]]\n\tat dalvik.system.BaseDexClassLoader.findClass(BaseDexClassLoader.java:196)\n\tat java.lang.ClassLoader.loadClass(ClassLoader.java:379)\n\tat java.lang.ClassLoader.loadClass(ClassLoader.java:312)\n\t... 24 more\n-------------------------------------": 9,
  ".zip": 9,
  "0": 9,
  "CANCEL": 8,
  "CLOSE": 8,
  "CREATE": 1,
  "Cloud Connection": 4,
  "Cut": 1,
  "DELETE": 1,
  "Delete": 1,
  "Delete Bookmark": 1,
  "Delete Permanently": 1,
  "Do you want to set current path as home for this tab?": 9,
  "Done": 8,
  "Enter Name": 9,
  "Folder name": 9,
  "Hide from media browsers": 7,
  "Home": 4,
  "LOST.DIR": 9,
  "List view": 5,
  "More options": 5,
  "Music.aes": 9,
  "Navigate up": 4,
  "OK": 8,
  "OPEN": 4,
  "Operation failed for following files\n1. Android": 9,
  "PASTE": 1,
  "Properties": 1,
  "REPORT THIS ERROR VIA TELEGRAM": 9,
  "Repeat password": 9,
  "RhXysYuf": 9,
  "SAVE": 1,
  "Search": 6,
  "Select all": 5,
  "Show roots": 5,
  "Size (smallest first)": 5,
  "T&w\r-": 9,
  "Type to search…": 6,
  "Use Amaze Encryption Format": 7
}

# 统计每个类别的数量
category_counts = Counter(button_labels.values())

# 打印结果
for category, count in sorted(category_counts.items()):
    print(f"类别 {category}：{count} 个")
# Out:
# 类别 1：9 个
# 类别 4：4 个
# 类别 5：5 个
# 类别 6：2 个
# 类别 7：2 个
# 类别 8：4 个
# 类别 9：14 个
