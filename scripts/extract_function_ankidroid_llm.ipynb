# %%
import os
import json
from glob import glob

# 设置事件目录路径
EVENT_DIR = r"C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output6\\events"

# 按时间顺序读取所有事件文件
event_files = sorted(glob(os.path.join(EVENT_DIR, "event_*.json")))

# 存储提取的数据
event_controls = []

for file_path in event_files:
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        event = data.get('event', {})
        view = event.get('view', {})
        
        control_info = {
            # 'tag': data.get('tag'),
            'event_type': event.get('event_type'),
            'class': view.get('class').split(".")[-1] if view.get('class') is not None else None ,
            'text': view.get('text'),
            'content_description': view.get('content_description'),
            'resource_id': view.get('resource_id'),
            # 'clickable': view.get('clickable'),
            # 'long_clickable': view.get('long_clickable'),
            # 'bounds': view.get('bounds'),
            # 'desc': view.get('desc'),
        }
        
        event_controls.append(control_info)
    
    except Exception as e:
        print(f"Failed to process {file_path}: {e}")

# ✅ 输出样例（前两项）
for item in event_controls[:10]:
    print(json.dumps(item, indent=2, ensure_ascii=False))
# Out:
# {
#   "event_type": "kill_app",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "intent",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "key",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "touch",
#   "class": "RelativeLayout",
#   "text": null,
#   "content_description": null,
#   "resource_id": "com.ichi2.anki.debug:id/DeckPickerHoriz"
# }
# {
#   "event_type": "long_touch",
#   "class": "ImageView",
#   "text": null,
#   "content_description": "More options",
#   "resource_id": null
# }
# {
#   "event_type": "long_touch",
#   "class": "Button",
#   "text": null,
#   "content_description": "Flag card",
#   "resource_id": "com.ichi2.anki.debug:id/action_flag"
# }
# {
#   "event_type": "long_touch",
#   "class": "FrameLayout",
#   "text": null,
#   "content_description": null,
#   "resource_id": "com.ichi2.anki.debug:id/touch_layer"
# }
# {
#   "event_type": "key",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "touch",
#   "class": "RelativeLayout",
#   "text": null,
#   "content_description": null,
#   "resource_id": "com.ichi2.anki.debug:id/DeckPickerHoriz"
# }
# {
#   "event_type": "scroll",
#   "class": "WebView",
#   "text": "AnkiDroid Flashcard",
#   "content_description": null,
#   "resource_id": null
# }

# %%
function_set=set()

for ctl in event_controls:
    text = ctl.get('text')
    content_description = ctl.get('content_description')
    
    if(text): function_set.add(text)
    elif(content_description): function_set.add(content_description)

function_set
# Out:
# {'(B"3nC9*',
#  "@3Xl6'",
#  'Allow only while using the app',
#  'Anki Manual',
#  'AnkiDroid',
#  'AnkiDroid FAQ',
#  'AnkiDroid Flashcard',
#  'AnkiDroid Manual',
#  'AnkiDroid Privacy Policy',
#  'AnkiWeb Privacy Policy',
#  'AnkiWeb Terms and Conditions',
#  'Attach multimedia content to the Back field',
#  'Attach multimedia content to the Front field',
#  'Back',
#  'Basic',
#  'Basic (and reversed card)',
#  'Basic (optional reversed card)',
#  'Basic (type in the answer)',
#  'Basic_',
#  'Browse cards',
#  'Cancel',
#  'Card 1',
#  'Card browser',
#  'Cards: Card 1',
#  'Clear text',
#  'Cloze',
#  'Collapse',
#  'Copy',
#  'Create shortcut',
#  'Create subdeck',
#  'Custom study',
#  'Deck',
#  'Deck Search',
#  'Deck options',
#  'Decks',
#  'Delete deck',
#  'Discard',
#  'Edit cards',
#  'Email address',
#  'Expand',
#  'Flag card',
#  'Format as Bold',
#  'Format as Italic',
#  'Front',
#  'Get Help',
#  'Get shared decks',
#  'Hide answer',
#  'Hide whiteboard',
#  'Home',
#  'Increasing intervals',
#  'Insert Heading',
#  'Insert Horizontal Line',
#  'Insert MathJax Equation',
#  'Keep Editing',
#  'Lapses',
#  'Latest added first',
#  'Learn More',
#  'Learning steps',
#  'Limit to particular tags',
#  'Log in',
#  'MYjARIN',
#  'More options',
#  'Most lapsed',
#  'Navigate up',
#  'New cards ignore review limit Affects the entire collection.',
#  'Open drawer',
#  'Open the deck overview page containing the number of cards to see today.',
#  'Password',
#  'Paste',
#  'Preview',
#  'Preview new cards',
#  'Privacy',
#  'Question',
#  'Random',
#  'Record Voice',
#  'Rename',
#  'Report a Bug',
#  'Reset password',
#  'Save',
#  'Search using deck name',
#  'Show answer',
#  'Show password',
#  'Show whiteboard',
#  'Sort Field',
#  'Statistics',
#  'Study',
#  'Study options',
#  'Tags: ',
#  'Tags: 英语例句',
#  'This deck',
#  'Toggle Mark',
#  'Using AnkiDroid',
#  'ZTg',
#  'all',
#  'deck',
#  'jUUIrZN',
#  'mReyc',
#  '{{Front}}',
#  '◄',
#  '不管怎样,受我支配的祈祷者总是坐地铁走向远方。'}

# %%
# import os
# import json
# import csv
# from glob import glob

# EVENT_DIR = r"C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output5\\events"
# IMG_DIR = r"C:\Users\HP\Desktop\kea\ecnusse\Kea\output5\view_images"
# VALID_TEXTS = function_set  # 你提供的控件文本集合

# output = []

# for file_path in sorted(glob(os.path.join(EVENT_DIR, "event_*.json"))):
#     with open(file_path, 'r', encoding='utf-8') as f:
#         data = json.load(f)
    
#     view = data.get("event", {}).get("view", {})
#     text = view.get("text")
#     desc = view.get("content_description")
    
#     label = text or desc
#     if label in VALID_TEXTS:
#         view_str = view.get("view_str")
#         image_file = f"view_{view_str}.png"
#         image_path = os.path.join(IMG_DIR, image_file)
        
#         output.append({
#             "label": label,
#             "view_str": view_str,
#             "image_path": image_path,
#             "class": view.get("class")
#         })

# # 导出为CSV（可用于人工分类）
# with open("control_views.csv", "w", newline='', encoding='utf-8') as f:
#     writer = csv.DictWriter(f, fieldnames=output[0].keys())
#     writer.writeheader()
#     writer.writerows(output)

# %%
from collections import Counter

button_labels = {
  "(B\"3nC9*": 9,
  "@3Xl6'": 9,
  "Allow only while using the app": 7,
  "Anki Manual": 9,
  "AnkiDroid": 9,
  "AnkiDroid FAQ": 9,
  "AnkiDroid Flashcard": 9,
  "AnkiDroid Manual": 9,
  "AnkiDroid Privacy Policy": 9,
  "AnkiWeb Privacy Policy": 9,
  "AnkiWeb Terms and Conditions": 9,
  "Attach multimedia content to the Back field": 1,
  "Attach multimedia content to the Front field": 1,
  "Back": 4,
  "Basic": 3,
  "Basic (and reversed card)": 3,
  "Basic (optional reversed card)": 3,
  "Basic (type in the answer)": 3,
  "Basic_": 3,
  "Browse cards": 4,
  "Cancel": 8,
  "Card 1": 9,
  "Card browser": 4,
  "Cards: Card 1": 9,
  "Clear text": 2,
  "Cloze": 3,
  "Collapse": 5,
  "Copy": 1,
  "Create shortcut": 1,
  "Create subdeck": 1,
  "Custom study": 4,
  "Deck": 9,
  "Deck Search": 6,
  "Deck options": 7,
  "Decks": 9,
  "Delete deck": 1,
  "Discard": 8,
  "Edit cards": 2,
  "Email address": 9,
  "Expand": 5,
  "Flag card": 1,
  "Format as Bold": 2,
  "Format as Italic": 2,
  "Front": 9,
  "Get Help": 8,
  "Get shared decks": 1,
  "Hide answer": 5,
  "Hide whiteboard": 5,
  "Home": 4,
  "Increasing intervals": 7,
  "Insert Heading": 2,
  "Insert Horizontal Line": 2,
  "Insert MathJax Equation": 2,
  "Keep Editing": 7,
  "Lapses": 9,
  "Latest added first": 5,
  "Learn More": 8,
  "Learning steps": 7,
  "Limit to particular tags": 7,
  "Log in": 4,
  "MYjARIN": 9,
  "More options": 5,
  "Most lapsed": 5,
  "Navigate up": 4,
  "New cards ignore review limit Affects the entire collection.": 7,
  "Open drawer": 5,
  "Open the deck overview page containing the number of cards to see today.": 9,
  "Password": 9,
  "Paste": 1,
  "Preview": 5,
  "Preview new cards": 5,
  "Privacy": 9,
  "Question": 9,
  "Random": 5,
  "Record Voice": 1,
  "Rename": 1,
  "Report a Bug": 8,
  "Reset password": 1,
  "Save": 1,
  "Search using deck name": 6,
  "Show answer": 5,
  "Show password": 5,
  "Show whiteboard": 5,
  "Sort Field": 5,
  "Statistics": 4,
  "Study": 4,
  "Study options": 7,
  "Tags: ": 9,
  "Tags: 英语例句": 9,
  "This deck": 9,
  "Toggle Mark": 1,
  "Using AnkiDroid": 9,
  "ZTg": 9,
  "all": 9,
  "deck": 9,
  "jUUIrZN": 9,
  "mReyc": 9,
  "{{Front}}": 9,
  "◄": 4,
  "不管怎样,受我支配的祈祷者总是坐地铁走向远方。": 9
}

# 统计每个类别的数量
category_counts = Counter(button_labels.values())

# 打印结果
for category, count in sorted(category_counts.items()):
    print(f"类别 {category}：{count} 个")
# Out:
# 类别 1：14 个
# 类别 2：7 个
# 类别 3：6 个
# 类别 4：10 个
# 类别 5：15 个
# 类别 6：2 个
# 类别 7：8 个
# 类别 8：5 个
# 类别 9：33 个
