# %%
import os
import json
from glob import glob

# 设置事件目录路径
EVENT_DIR = r"C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output42\\events"

# 按时间顺序读取所有事件文件
event_files = sorted(glob(os.path.join(EVENT_DIR, "event_*.json")))

# 存储提取的数据
event_controls = []

for file_path in event_files:
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        event = data.get('event', {})
        view = event.get('view', {})
        
        control_info = {
            # 'tag': data.get('tag'),
            'event_type': event.get('event_type'),
            'class': view.get('class').split(".")[-1] if view.get('class') is not None else None ,
            'text': view.get('text'),
            'content_description': view.get('content_description'),
            'resource_id': view.get('resource_id'),
            # 'clickable': view.get('clickable'),
            # 'long_clickable': view.get('long_clickable'),
            # 'bounds': view.get('bounds'),
            # 'desc': view.get('desc'),
        }
        
        event_controls.append(control_info)
    
    except Exception as e:
        print(f"Failed to process {file_path}: {e}")

# ✅ 输出样例（前两项）
for item in event_controls[:10]:
    print(json.dumps(item, indent=2, ensure_ascii=False))
# Out:
# Failed to process C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output42\\events\event_2025-05-06_174606.json: Expecting value: line 1 column 1 (char 0)
# {
#   "event_type": "kill_app",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "intent",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "touch",
#   "class": "ImageView",
#   "text": null,
#   "content_description": "More options",
#   "resource_id": null
# }
# {
#   "event_type": "touch",
#   "class": "LinearLayout",
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "touch",
#   "class": "TextView",
#   "text": null,
#   "content_description": "Sort",
#   "resource_id": "it.feio.android.omninotes.alpha:id/menu_sort"
# }
# {
#   "event_type": "touch",
#   "class": "RadioButton",
#   "text": null,
#   "content_description": null,
#   "resource_id": "it.feio.android.omninotes.alpha:id/radio"
# }
# {
#   "event_type": "touch",
#   "class": "TextView",
#   "text": "Nothing here!",
#   "content_description": null,
#   "resource_id": "it.feio.android.omninotes.alpha:id/empty_list"
# }
# {
#   "event_type": "long_touch",
#   "class": "TextView",
#   "text": null,
#   "content_description": "Sort",
#   "resource_id": "it.feio.android.omninotes.alpha:id/menu_sort"
# }
# {
#   "event_type": "long_touch",
#   "class": "TextView",
#   "text": null,
#   "content_description": "Sort",
#   "resource_id": "it.feio.android.omninotes.alpha:id/menu_sort"
# }
# {
#   "event_type": "touch",
#   "class": "ImageButton",
#   "text": null,
#   "content_description": null,
#   "resource_id": "it.feio.android.omninotes.alpha:id/fab_expand_menu_button"
# }

# %%
function_set=set()

for ctl in event_controls:
    text = ctl.get('text')
    content_description = ctl.get('content_description')
    
    if(text): function_set.add(text)
    elif(content_description): function_set.add(content_description)

function_set
# Out:
# {'\nCE',
#  '\r6\r\nZ Tj',
#  '#',
#  "'Puv",
#  '+skVBC',
#  '/Ek;',
#  '10',
#  '10:41 AM',
#  '34',
#  '35',
#  '37.4219983, -122.084',
#  '43',
#  '5/6/25 9:38 AM \n\n',
#  '5O\\XA ',
#  '9',
#  ':HTt',
#  'A=j)/',
#  'ADD CATEGORY',
#  'Add tags',
#  'Answer',
#  'App info',
#  'Attachment',
#  'BACK',
#  'BGMD}\rKC  ',
#  'CANCEL',
#  'CGhLXsGb',
#  'CONFIRM',
#  'CUSTOM',
#  'CUSTOM…',
#  'Category',
#  'Checklist',
#  'Clear query',
#  'Close app',
#  'Collapse',
#  'Confirm answer',
#  'Confirm the new password',
#  'Confirm undoing changes?',
#  'Content',
#  'DONE',
#  'Deny',
#  'Documents',
#  'Done',
#  'EVERY YEAR',
#  'FF8BC34A',
#  'FFEC407A',
#  'Files',
#  'FiywYIjw',
#  'FopdnUUT',
#  'GtuhuvCW',
#  'Insert a new password',
#  'KCt ./',
#  'Location',
#  'MAY 6, 2025',
#  'More options',
#  'New item',
#  'Nothing here!',
#  'OK',
#  'PASSWORD FORGOTTEN',
#  'PM',
#  'PRESETS',
#  'Previous month',
#  'Pushbullet',
#  'QFaDlXe',
#  'Question',
#  'REMOVE CATEGORY',
#  'REMOVE PASSWORD',
#  'REPEAT DAILY',
#  'Record',
#  'Remove location?',
#  'Remove reminder?',
#  'Search',
#  'Search in notes',
#  'Search location',
#  'Share',
#  'Sort',
#  'T',
#  'Tags',
#  'Timestamp',
#  'Title',
#  'USE CURRENT LOCATION',
#  'Video',
#  'Voice search',
#  'WJ',
#  'WlqpP',
#  'ZSt7E',
#  'b0Gt$26*',
#  'cf',
#  'drawer open',
#  'hHCr',
#  'l',
#  'nK',
#  'ngXPA',
#  'oKgUJ',
#  'oKgUJ\ny\n\n#Tag1',
#  'p?Bl;o;y',
#  'q\\',
#  'ss',
#  'w]PU[,bW',
#  'y',
#  '•',
#  '••',
#  '•••',
#  '••••••',
#  '••••••••'}

# %%
# import os
# import json
# import csv
# from glob import glob

# EVENT_DIR = r"C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output5\\events"
# IMG_DIR = r"C:\Users\HP\Desktop\kea\ecnusse\Kea\output5\view_images"
# VALID_TEXTS = function_set  # 你提供的控件文本集合

# output = []

# for file_path in sorted(glob(os.path.join(EVENT_DIR, "event_*.json"))):
#     with open(file_path, 'r', encoding='utf-8') as f:
#         data = json.load(f)
    
#     view = data.get("event", {}).get("view", {})
#     text = view.get("text")
#     desc = view.get("content_description")
    
#     label = text or desc
#     if label in VALID_TEXTS:
#         view_str = view.get("view_str")
#         image_file = f"view_{view_str}.png"
#         image_path = os.path.join(IMG_DIR, image_file)
        
#         output.append({
#             "label": label,
#             "view_str": view_str,
#             "image_path": image_path,
#             "class": view.get("class")
#         })

# # 导出为CSV（可用于人工分类）
# with open("control_views.csv", "w", newline='', encoding='utf-8') as f:
#     writer = csv.DictWriter(f, fieldnames=output[0].keys())
#     writer.writeheader()
#     writer.writerows(output)

# %%
from collections import Counter

button_labels = {
    "ADD CATEGORY": 1,
    "Add tags": 1,
    "Answer": 9,
    "App info": 7,
    "Attachment": 9,
    "BACK": 4,
    "CANCEL": 8,
    "CONFIRM": 8,
    "CUSTOM": 3,
    "CUSTOM…": 3,
    "Category": 9,
    "Checklist": 2,
    "Clear query": 6,
    "Close app": 4,
    "Collapse": 5,
    "Confirm answer": 9,
    "Confirm the new password": 9,
    "Confirm undoing changes?": 9,
    "Content": 9,
    "DONE": 8,
    "Deny": 8,
    "Documents": 9,
    "Done": 8,
    "EVERY YEAR": 3,
    "FF8BC34A": 9,
    "FFEC407A": 9,
    "Files": 9,
    "Insert a new password": 9,
    "Location": 9,
    "MAY 6, 2025": 9,
    "More options": 5,
    "New item": 1,
    "Nothing here!": 9,
    "OK": 8,
    "PASSWORD FORGOTTEN": 4,
    "PM": 3,
    "PRESETS": 3,
    "Previous month": 4,
    "Pushbullet": 9,
    "Question": 9,
    "REMOVE CATEGORY": 1,
    "REMOVE PASSWORD": 1,
    "REPEAT DAILY": 3,
    "Record": 9,
    "Remove location?": 1,
    "Remove reminder?": 1,
    "Search": 6,
    "Search in notes": 6,
    "Search location": 6,
    "Share": 1,
    "Sort": 5,
    "Tags": 9,
    "Timestamp": 3,
    "Title": 9,
    "USE CURRENT LOCATION": 4,
    "Video": 9,
    "Voice search": 6,
    "drawer open": 5,
    "#": 9,
    "'Puv": 9,
    "+skVBC": 9,
    "/Ek;": 9,
    "10": 9,
    "10:41 AM": 3,
    "34": 9,
    "35": 9,
    "37.4219983, -122.084": 9,
    "43": 9,
    "5/6/25 9:38 AM \n\n": 3,
    "5O\\XA ": 9,
    "9": 9,
    ":HTt": 9,
    "A=j)/": 9,
    "CE": 9,
    "CGhLXsGb": 9,
    "CUSTOM": 3,
    "FiywYIjw": 9,
    "FopdnUUT": 9,
    "GtuhuvCW": 9,
    "KCt ./": 9,
    "QFaDlXe": 9,
    "WJ": 9,
    "WlqpP": 9,
    "ZSt7E": 9,
    "b0Gt$26*": 9,
    "cf": 9,
    "hHCr": 9,
    "l": 9,
    "nK": 9,
    "ngXPA": 9,
    "oKgUJ": 9,
    "oKgUJ\ny\n\n#Tag1": 9,
    "p?Bl;o;y": 9,
    "q\\": 9,
    "ss": 9,
    "w]PU[,bW": 9,
    "y": 9,
    "•": 2,
    "••": 2,
    "•••": 2,
    "••••••": 2,
    "••••••••": 2,
    "\r6\r\nZ Tj": 9,
    "BGMD}\rKC  ": 9
}






# 统计每个类别的数量
category_counts = Counter(button_labels.values())

# 打印结果
for category, count in sorted(category_counts.items()):
    print(f"类别 {category}：{count} 个")
# Out:
# 类别 1：8 个
# 类别 2：6 个
# 类别 3：9 个
# 类别 4：5 个
# 类别 5：4 个
# 类别 6：5 个
# 类别 7：1 个
# 类别 8：6 个
# 类别 9：59 个
