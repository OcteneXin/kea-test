# %%
import os
import json
from glob import glob

# 设置事件目录路径
EVENT_DIR = r"C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output41\\events"

# 按时间顺序读取所有事件文件
event_files = sorted(glob(os.path.join(EVENT_DIR, "event_*.json")))

# 存储提取的数据
event_controls = []

for file_path in event_files:
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        event = data.get('event', {})
        view = event.get('view', {})
        
        control_info = {
            # 'tag': data.get('tag'),
            'event_type': event.get('event_type'),
            'class': view.get('class').split(".")[-1] if view.get('class') is not None else None ,
            'text': view.get('text'),
            'content_description': view.get('content_description'),
            'resource_id': view.get('resource_id'),
            # 'clickable': view.get('clickable'),
            # 'long_clickable': view.get('long_clickable'),
            # 'bounds': view.get('bounds'),
            # 'desc': view.get('desc'),
        }
        
        event_controls.append(control_info)
    
    except Exception as e:
        print(f"Failed to process {file_path}: {e}")

# ✅ 输出样例（前两项）
for item in event_controls[:10]:
    print(json.dumps(item, indent=2, ensure_ascii=False))
# Out:
# {
#   "event_type": "kill_app",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "intent",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "long_touch",
#   "class": "ImageView",
#   "text": null,
#   "content_description": "More options",
#   "resource_id": null
# }
# {
#   "event_type": "long_touch",
#   "class": "LinearLayout",
#   "text": null,
#   "content_description": null,
#   "resource_id": "it.feio.android.omninotes.alpha:id/reminder_layout"
# }
# {
#   "event_type": "key",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "long_touch",
#   "class": "ImageView",
#   "text": null,
#   "content_description": "More options",
#   "resource_id": null
# }
# {
#   "event_type": "long_touch",
#   "class": "LinearLayout",
#   "text": null,
#   "content_description": null,
#   "resource_id": "it.feio.android.omninotes.alpha:id/reminder_layout"
# }
# {
#   "event_type": "long_touch",
#   "class": "TextView",
#   "text": "Remove reminder?",
#   "content_description": null,
#   "resource_id": "it.feio.android.omninotes.alpha:id/md_content"
# }
# {
#   "event_type": "touch",
#   "class": "TextView",
#   "text": "Remove reminder?",
#   "content_description": null,
#   "resource_id": "it.feio.android.omninotes.alpha:id/md_content"
# }
# {
#   "event_type": "key",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }

# %%
function_set=set()

for ctl in event_controls:
    text = ctl.get('text')
    content_description = ctl.get('content_description')
    
    if(text): function_set.add(text)
    elif(content_description): function_set.add(content_description)

function_set
# Out:
# {'(a',
#  ',f.,C)^p',
#  '3\nN[hj$N',
#  '7',
#  '>j-(z',
#  'ADD CATEGORY',
#  'Add tags',
#  'Allow all the time',
#  'Attachment',
#  'BjajTEme',
#  'CANCEL',
#  'CONFIRM',
#  'CUSTOM…',
#  'Category',
#  'Checklist',
#  'Clear query',
#  'Collapse',
#  'Colors',
#  'Community',
#  'Confirm deleting all trashed notes?',
#  'Content',
#  'Done',
#  'EVERY WEEK',
#  'Erase sketch?',
#  'Eraser',
#  'Files',
#  'Fix Backups restoration on Android 12+',
#  'Improved! Password is required when importing backups containing protected notes',
#  'LPfs',
#  'Location',
#  'MAY 6, 2025',
#  'More options',
#  'Navigate up',
#  'New! Open source transparent crashes reporting available on acra.omninotes.app (user: guest, pass: guest)',
#  'New! Removed all analytics',
#  'New! Updated to Android 11 to get latest fixes and improvements IMPORTANT: This will require to move your old backups to the new directory ',
#  'Nothing here!',
#  'OFF',
#  'OK',
#  'ON',
#  'OQaH',
#  'Pushbullet',
#  'Q',
#  'REMOVE CATEGORY',
#  'Record',
#  'Remove reminder?',
#  'Search',
#  'Search in notes',
#  'Search location',
#  'Share',
#  'Sketch',
#  'Sort',
#  'Stop',
#  'Stroke',
#  'Tags',
#  'Timestamp',
#  'Title',
#  'USE CURRENT LOCATION',
#  'Video',
#  'Voice search',
#  'ZYHXoHmF',
#  'drawer closed',
#  'drawer open',
#  'g/$57W@L',
#  'gn',
#  'iO,',
#  'o',
#  'qxw',
#  'read a book #Tag1'}

# %%
# import os
# import json
# import csv
# from glob import glob

# EVENT_DIR = r"C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output5\\events"
# IMG_DIR = r"C:\Users\HP\Desktop\kea\ecnusse\Kea\output5\view_images"
# VALID_TEXTS = function_set  # 你提供的控件文本集合

# output = []

# for file_path in sorted(glob(os.path.join(EVENT_DIR, "event_*.json"))):
#     with open(file_path, 'r', encoding='utf-8') as f:
#         data = json.load(f)
    
#     view = data.get("event", {}).get("view", {})
#     text = view.get("text")
#     desc = view.get("content_description")
    
#     label = text or desc
#     if label in VALID_TEXTS:
#         view_str = view.get("view_str")
#         image_file = f"view_{view_str}.png"
#         image_path = os.path.join(IMG_DIR, image_file)
        
#         output.append({
#             "label": label,
#             "view_str": view_str,
#             "image_path": image_path,
#             "class": view.get("class")
#         })

# # 导出为CSV（可用于人工分类）
# with open("control_views.csv", "w", newline='', encoding='utf-8') as f:
#     writer = csv.DictWriter(f, fieldnames=output[0].keys())
#     writer.writeheader()
#     writer.writerows(output)

# %%
from collections import Counter

button_labels = {
    "ADD CATEGORY": 1,
    "Add tags": 1,
    "Allow all the time": 7,
    "Attachment": 9,
    "CANCEL": 8,
    "CONFIRM": 8,
    "CUSTOM…": 3,
    "Category": 9,
    "Checklist": 2,
    "Clear query": 6,
    "Collapse": 5,
    "Colors": 3,
    "Community": 9,
    "Confirm deleting all trashed notes?": 9,
    "Content": 9,
    "Done": 8,
    "EVERY WEEK": 3,
    "Erase sketch?": 9,
    "Eraser": 2,
    "Files": 9,
    "Fix Backups restoration on Android 12+": 7,
    "Improved! Password is required when importing backups containing protected notes": 9,
    "Location": 9,
    "MAY 6, 2025": 9,
    "More options": 5,
    "Navigate up": 4,
    "New! Open source transparent crashes reporting available on acra.omninotes.app (user: guest, pass: guest)": 9,
    "New! Removed all analytics": 9,
    "New! Updated to Android 11 to get latest fixes and improvements IMPORTANT: This will require to move your old backups to the new directory ": 9,
    "Nothing here!": 9,
    "OFF": 7,
    "OK": 8,
    "ON": 7,
    "Pushbullet": 9,
    "REMOVE CATEGORY": 1,
    "Record": 9,
    "Remove reminder?": 1,
    "Search": 6,
    "Search in notes": 6,
    "Search location": 6,
    "Share": 1,
    "Sketch": 2,
    "Sort": 5,
    "Stop": 9,
    "Stroke": 2,
    "Tags": 9,
    "Timestamp": 3,
    "Title": 9,
    "USE CURRENT LOCATION": 4,
    "Video": 9,
    "Voice search": 6,
    "drawer closed": 5,
    "drawer open": 5,
    "3\nN[hj$N": 9,
    "(a": 9,
    ",f.,C)^p": 9,
    "7": 9,
    ">j-(z": 9,
    "BjajTEme": 9,
    "LPfs": 9,
    "OQaH": 9,
    "Q": 9,
    "ZYHXoHmF": 9,
    "g/$57W@L": 9,
    "gn": 9,
    "iO,": 9,
    "o": 9,
    "qxw": 9,
    "read a book #Tag1": 9
}






# 统计每个类别的数量
category_counts = Counter(button_labels.values())

# 打印结果
for category, count in sorted(category_counts.items()):
    print(f"类别 {category}：{count} 个")
# Out:
# 类别 1：5 个
# 类别 2：4 个
# 类别 3：4 个
# 类别 4：2 个
# 类别 5：5 个
# 类别 6：5 个
# 类别 7：4 个
# 类别 8：4 个
# 类别 9：36 个
