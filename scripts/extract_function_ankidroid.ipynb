# %%
import os
import json
from glob import glob

# 设置事件目录路径
EVENT_DIR = r"C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output62\\events"

# 按时间顺序读取所有事件文件
event_files = sorted(glob(os.path.join(EVENT_DIR, "event_*.json")))

# 存储提取的数据
event_controls = []

for file_path in event_files:
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        event = data.get('event', {})
        view = event.get('view', {})
        
        control_info = {
            # 'tag': data.get('tag'),
            'event_type': event.get('event_type'),
            'class': view.get('class').split(".")[-1] if view.get('class') is not None else None ,
            'text': view.get('text'),
            'content_description': view.get('content_description'),
            'resource_id': view.get('resource_id'),
            # 'clickable': view.get('clickable'),
            # 'long_clickable': view.get('long_clickable'),
            # 'bounds': view.get('bounds'),
            # 'desc': view.get('desc'),
        }
        
        event_controls.append(control_info)
    
    except Exception as e:
        print(f"Failed to process {file_path}: {e}")

# ✅ 输出样例（前两项）
for item in event_controls[:10]:
    print(json.dumps(item, indent=2, ensure_ascii=False))
# Out:
# {
#   "event_type": "kill_app",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "intent",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "key",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "long_touch",
#   "class": "ImageView",
#   "text": null,
#   "content_description": "More options",
#   "resource_id": null
# }
# {
#   "event_type": "touch",
#   "class": "ImageButton",
#   "text": null,
#   "content_description": "Open drawer",
#   "resource_id": null
# }
# {
#   "event_type": "touch",
#   "class": "CheckedTextView",
#   "text": "Decks",
#   "content_description": null,
#   "resource_id": "com.ichi2.anki.debug:id/design_menu_item_text"
# }
# {
#   "event_type": "touch",
#   "class": "LinearLayout",
#   "text": null,
#   "content_description": "Open the deck overview page containing the number of cards to see today.",
#   "resource_id": "com.ichi2.anki.debug:id/counts_layout"
# }
# {
#   "event_type": "touch",
#   "class": "ImageButton",
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }
# {
#   "event_type": "touch",
#   "class": "LinearLayout",
#   "text": null,
#   "content_description": "Open the deck overview page containing the number of cards to see today.",
#   "resource_id": "com.ichi2.anki.debug:id/counts_layout"
# }
# {
#   "event_type": "key",
#   "class": null,
#   "text": null,
#   "content_description": null,
#   "resource_id": null
# }

# %%
function_set=set()

for ctl in event_controls:
    text = ctl.get('text')
    content_description = ctl.get('content_description')
    
    if(text): function_set.add(text)
    elif(content_description): function_set.add(content_description)

function_set
# Out:
# {'*',
#  '+:ZzbQ|5',
#  '.card {\n font-family: arial;\n font-size: 20px;\n text-align: center;\n color: black;\n background-color: white;\n}',
#  '108. At the dawn on the lawn the yawning drowned man began to frown.',
#  '@8',
#  'Add',
#  'AnkiDroid',
#  'AnkiDroid Flashcard',
#  'Answer',
#  'Attach multimedia content to the Back field',
#  'Attach multimedia content to the Front field',
#  'Basic',
#  'Basic (and reversed card)',
#  'Basic (optional reversed card)',
#  'Basic (type in the answer)',
#  'Basic_',
#  'Button text',
#  'Cancel',
#  'Card Modified',
#  'Card browser',
#  'Cards: Card 1',
#  'Cloze',
#  'Collapse',
#  'Create',
#  'Create Toolbar Item',
#  'Decks',
#  'Discard',
#  'Due',
#  'EeATkU',
#  'Email address',
#  'Expand',
#  'Filter decks',
#  'Filtered Deck 07:18',
#  'Flag card',
#  'Format as Bold',
#  'HTML After Selection',
#  'HTML Before Selection',
#  'Insert Horizontal Line',
#  'Interval',
#  'Keep Editing',
#  'Learn More',
#  'Log in',
#  'More options',
#  'Most lapsed',
#  'Navigate up',
#  'Note Type',
#  'OK',
#  'Open drawer',
#  'Open the deck overview page containing the number of cards to see today.',
#  'Password',
#  'Preview',
#  'Question',
#  'Rename',
#  'Reset password',
#  'Reviews',
#  'RgAua}~T',
#  'Save',
#  'Search',
#  'Select all',
#  'Show password',
#  'Sort Field',
#  'Study options',
#  'Styling',
#  'This is a special deck for studying outside of the normal schedule. Cards will be automatically returned to their original decks after you review them. Deleting this deck from the deck list will return all remaining cards to their original deck.',
#  'Toggle Mark',
#  'kErQbDdc',
#  'myGJthiy',
#  'n',
#  '{{Front}}',
#  '除了不诚实的人外,任何诚实的人都能得到蜂蜜,人人都这么想。'}

# %%
# import os
# import json
# import csv
# from glob import glob

# EVENT_DIR = r"C:\\Users\\HP\\Desktop\\kea\\ecnusse\\Kea\\output5\\events"
# IMG_DIR = r"C:\Users\HP\Desktop\kea\ecnusse\Kea\output5\view_images"
# VALID_TEXTS = function_set  # 你提供的控件文本集合

# output = []

# for file_path in sorted(glob(os.path.join(EVENT_DIR, "event_*.json"))):
#     with open(file_path, 'r', encoding='utf-8') as f:
#         data = json.load(f)
    
#     view = data.get("event", {}).get("view", {})
#     text = view.get("text")
#     desc = view.get("content_description")
    
#     label = text or desc
#     if label in VALID_TEXTS:
#         view_str = view.get("view_str")
#         image_file = f"view_{view_str}.png"
#         image_path = os.path.join(IMG_DIR, image_file)
        
#         output.append({
#             "label": label,
#             "view_str": view_str,
#             "image_path": image_path,
#             "class": view.get("class")
#         })

# # 导出为CSV（可用于人工分类）
# with open("control_views.csv", "w", newline='', encoding='utf-8') as f:
#     writer = csv.DictWriter(f, fieldnames=output[0].keys())
#     writer.writeheader()
#     writer.writerows(output)

# %%
from collections import Counter

button_labels = {
  "*": 9,
  "+:ZzbQ|5": 9,
  ".card {\n font-family: arial;\n font-size: 20px;\n text-align: center;\n color: black;\n background-color: white;\n}": 9,
  "108. At the dawn on the lawn the yawning drowned man began to frown.": 9,
  "@8": 9,
  "Add": 1,
  "AnkiDroid": 9,
  "AnkiDroid Flashcard": 9,
  "Answer": 9,
  "Attach multimedia content to the Back field": 1,
  "Attach multimedia content to the Front field": 1,
  "Basic": 3,
  "Basic (and reversed card)": 3,
  "Basic (optional reversed card)": 3,
  "Basic (type in the answer)": 3,
  "Basic_": 3,
  "Button text": 9,
  "Cancel": 8,
  "Card Modified": 9,
  "Card browser": 4,
  "Cards: Card 1": 9,
  "Cloze": 3,
  "Collapse": 5,
  "Create": 1,
  "Create Toolbar Item": 1,
  "Decks": 9,
  "Discard": 8,
  "Due": 9,
  "EeATkU": 9,
  "Email address": 9,
  "Expand": 5,
  "Filter decks": 6,
  "Filtered Deck 07:18": 9,
  "Flag card": 1,
  "Format as Bold": 2,
  "HTML After Selection": 2,
  "HTML Before Selection": 2,
  "Insert Horizontal Line": 2,
  "Interval": 7,
  "Keep Editing": 7,
  "Learn More": 8,
  "Log in": 4,
  "More options": 5,
  "Most lapsed": 5,
  "Navigate up": 4,
  "Note Type": 9,
  "OK": 8,
  "Open drawer": 5,
  "Open the deck overview page containing the number of cards to see today.": 9,
  "Password": 9,
  "Preview": 5,
  "Question": 9,
  "Rename": 1,
  "Reset password": 1,
  "Reviews": 9,
  "RgAua}~T": 9,
  "Save": 1,
  "Search": 6,
  "Select all": 5,
  "Show password": 5,
  "Sort Field": 5,
  "Study options": 7,
  "Styling": 3,
  "This is a special deck for studying outside of the normal schedule. Cards will be automatically returned to their original decks after you review them. Deleting this deck from the deck list will return all remaining cards to their original deck.": 9,
  "Toggle Mark": 1,
  "kErQbDdc": 9,
  "myGJthiy": 9,
  "n": 9,
  "{{Front}}": 9,
  "除了不诚实的人外,任何诚实的人都能得到蜂蜜,人人都这么想。": 9
}


# 统计每个类别的数量
category_counts = Counter(button_labels.values())

# 打印结果
for category, count in sorted(category_counts.items()):
    print(f"类别 {category}：{count} 个")
# Out:
# 类别 1：10 个
# 类别 2：4 个
# 类别 3：7 个
# 类别 4：3 个
# 类别 5：9 个
# 类别 6：2 个
# 类别 7：3 个
# 类别 8：4 个
# 类别 9：28 个
